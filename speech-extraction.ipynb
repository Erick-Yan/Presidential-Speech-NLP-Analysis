# %%
from __future__ import print_function
import urllib.request, json, urllib.parse , requests, sys
import pandas as pd
import random

# %% [markdown]
# ## 1. Data Gathering

# %% [markdown]
# ### 1.1 Extract Speeches

# %%
republican_list = [
    'Chester A. Arthur',
    'George H. W. Bush',
    'George W. Bush',
    'Calvin Coolidge',
    'Dwight D. Eisenhower',
    'Gerald Ford',
    'James A. Garfield',
    'Ulysses S. Grant',
    'Warren G. Harding',
    'Benjamin Harrison',
    'Rutherford B. Hayes',
    'Herbert Hoover',
    'William McKinley',
    'Richard M. Nixon',
    'Ronald Reagan',
    'Theodore Roosevelt',
    'William Taft',
    'Donald Trump'
]

democratic_list = [
    'Joe Biden',
    'James Buchanan',
    'Jimmy Carter',
    'Grover Cleveland',
    'Bill Clinton',
    'Andrew Jackson',
    'Andrew Johnson',
    'Lyndon B. Johnson',
    'John F. Kennedy',
    'Barack Obama',
    'Franklin Pierce',
    'James K. Polk',
    'Franklin D. Roosevelt',
    'Harry S. Truman',
    'Martin Van Buren',
    'Woodrow Wilson'
]

# %%
endpoint = "https://api.millercenter.org/speeches"

r = requests.post(url = endpoint)
data = r.json()
party_speeches = data["Items"]

while 'LastEvaluatedKey' in data:
  parameters = {"continue_president": data['LastEvaluatedKey']['president'], 
                "continue_doc_name": data['LastEvaluatedKey']['doc_name']}
  r = requests.post(url = endpoint, params = parameters)
  data = r.json()
  party_speeches += data["Items"]

# %% [markdown]
# ### 1.2 Stratify and Random Sample for each Party

# %%
party_speeches_df = pd.DataFrame(party_speeches)
party_speeches_df.head()
# Out:
#                                                doc_name        date  \
# 0                   april-18-1977-address-nation-energy  1977-04-18
# 1           april-25-1980-statement-iran-rescue-mission  1980-04-25
# 2     august-14-1980-acceptance-speech-democratic-na...  1980-08-14
# 3     december-15-1978-speech-establishing-diplomati...  1978-12-15
# 4         february-2-1977-report-american-people-energy  1977-02-02
# ...                                                 ...         ...
# 1033               december-4-1883-third-annual-message  1883-12-04
# 1034               december-6-1881-first-annual-message  1881-12-06
# 1035           july-1-1882-veto-safety-regulations-bill  1882-07-01
# 1036  july-1-1884-message-regarding-settlement-india...  1884-07-01
# 1037  september-22-1881-address-upon-assuming-office...  1881-09-22
#
#                                              transcript          president  \
# 0     Good evening.\r\nTonight I want to have an unp...       Jimmy Carter
# 1     Late yesterday, I cancelled a carefully planne...       Jimmy Carter
# 2     Fellow Democrats, fellow citizens:\r\n\r\nI th...       Jimmy Carter
# 3     Good evening.\r\nI would like to read a joint ...       Jimmy Carter
# 4     Good evening.\r\nTomorrow will be two weeks si...       Jimmy Carter
# ...                                                 ...                ...
# 1033  To the Congress of the United States: At the t...  Chester A. Arthur
# 1034  To the Senate and House of Representatives of ...  Chester A. Arthur
# 1035  To the House of Representatives of the United ...  Chester A. Arthur
# 1036  By the President of the United States of Ameri...  Chester A. Arthur
# 1037  For the fourth time in the history of the Repu...  Chester A. Arthur
#
#                                                   title
# 0       April 18, 1977: Address to the Nation on Energy
# 1     April 25, 1980: Statement on the Iran Rescue M...
# 2     August 14, 1980: Acceptance Speech at the Demo...
# 3     December 15, 1978: Speech on Establishing Dipl...
# 4     February 2, 1977: Report to the American Peopl...
# ...                                                 ...
# 1033             December 4, 1883: Third Annual Message
# 1034             December 6, 1881: First Annual Message
# 1035      July 1, 1882: Veto of Safety Regulations Bill
# 1036  July 1, 1884: Message Regarding Settlement on ...
# 1037  September 22, 1881: Address Upon Assuming the ...
#
# [1038 rows x 5 columns]

# %%
republican_speeches_df, democratic_speeches_df = pd.DataFrame(), pd.DataFrame()
for index, row in party_speeches_df.iterrows():
    if row["president"] in republican_list:
        republican_speeches_df = republican_speeches_df.append(row)
    elif row["president"] in democratic_list:
        democratic_speeches_df = democratic_speeches_df.append(row)

democratic_speeches_df.reset_index(drop = True, inplace=True)
republican_speeches_df.reset_index(drop = True, inplace=True)

# %%
republican_rand_indices, democratic_rand_indices = list(), list()

while len(republican_rand_indices) < 50:
    rand_republican = random.randint(0, len(republican_speeches_df)-1)
    if rand_republican not in republican_rand_indices:
        republican_rand_indices.append(rand_republican) 

while len(democratic_rand_indices) < 50:
    rand_democrat = random.randint(0, len(democratic_speeches_df)-1)
    if rand_democrat not in democratic_rand_indices:
        democratic_rand_indices.append(rand_democrat)

# %%
for index, row in republican_speeches_df.iterrows():
    if index not in republican_rand_indices:
        republican_speeches_df.drop(index, inplace=True)

for index, row in democratic_speeches_df.iterrows():
    if index not in democratic_rand_indices:
        democratic_speeches_df.drop(index, inplace=True)

# %%
rs_democratic_speeches_df = democratic_speeches_df.copy()
rs_democratic_speeches_df.head(3)
# Out:
#                                              doc_name        date  \
# 10                  january-4-1980-speech-afghanistan  1980-01-04
# 27                  january-20-1949-inaugural-address  1949-01-20
# 32  march-15-1952-columbia-scholastic-press-associ...  1952-03-15
#
#                                            transcript        president  \
# 10   \r\n\r\nI come to you this evening to discuss...     Jimmy Carter
# 27  Mr. Vice President, Mr. Chief Justice, fellow ...  Harry S. Truman
# 32  Dr. Murphy, distinguished guests, Mr. Mayor, d...  Harry S. Truman
#
#                                                 title
# 10             January 4, 1980: Speech on Afghanistan
# 27                January 20, 1949: Inaugural Address
# 32  March 15, 1952: Columbia Scholastic Press Asso...

# %%
rs_republican_speeches_df = republican_speeches_df.copy()
rs_republican_speeches_df.head(3)
# Out:
#                                             doc_name        date  \
# 2  april-23-1898-proclamation-calling-military-vo...  1898-04-23
# 8  july-24-1897-message-regarding-banking-and-cur...  1897-07-24
# 9  march-15-1897-message-regarding-special-sessio...  1897-03-15
#
#                                           transcript         president  \
# 2  By the President of the United States of Ameri...  William McKinley
# 8  To the Congress of the United States:\nIn my m...  William McKinley
# 9  To the Congress of the United States:\nRegrett...  William McKinley
#
#                                                title
# 2  April 23, 1898: Proclamation Calling for Milit...
# 8  July 24, 1897: Message Regarding Banking and C...
# 9  March 15, 1897: Message Regarding Special Sess...

# %% [markdown]
# ## 2. NLP Analysis

# %% [markdown]
# ### 2.1 Preprocessing

# %%
import string
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
import nltk
from nltk.stem import WordNetLemmatizer

# %%
punctuation_strings = string.punctuation+("’")
spacy_stop_words = list(STOP_WORDS)
nlp = English()
nlp_lemm = spacy.load("en_core_web_sm")

# %%
# Remove stop words from text and calculate average # of words per sentence.
def clean_text(text):
    tokenized_sentences = nltk.sent_tokenize(text)
    word_tokens = list()
    total_sentence_len = 0
    for tokenized_sentence in tokenized_sentences:
        doc = nlp_lemm(tokenized_sentence)
        sentence_words = [word.lemma_.lower() for word in doc 
                    if str(word).lower() not in spacy_stop_words and 
                    str(word).lower() not in punctuation_strings and 
                    not nlp.vocab[str(word)].is_stop and
                    not str(word).lower().isdigit() and
                    str(word).isalpha()]
        # lemmatizer = WordNetLemmatizer()
        # sentence_words = [lemmatizer.lemmatize(word.lower()) for word in nltk.word_tokenize(tokenized_sentence) 
        #             if word.lower() not in spacy_stop_words and 
        #             word.lower() not in punctuation_strings and 
        #             not nlp.vocab[word].is_stop and
        #             not word.lower().isdigit() and
        #             word.isalpha()]
        total_sentence_len += len(sentence_words)
        word_tokens += sentence_words
        
    return {"Word Tokens": word_tokens, "Average Sentence Length": total_sentence_len / len(tokenized_sentences)}

# %%
def clean_df_text(df):
    clean_transcript, avg_sentence_length = [], []
    for index, row in df.iterrows():
        clean_text_output = clean_text(row["transcript"])
        clean_transcript.append(clean_text_output["Word Tokens"])
        avg_sentence_length.append(clean_text_output["Average Sentence Length"])
    df["clean transcript"] = clean_transcript
    df["avg_sentence_length"] = avg_sentence_length

# %%
clean_df_text(rs_republican_speeches_df)
clean_df_text(rs_democratic_speeches_df)

# %%
rs_democratic_speeches_df
# Out:
#                                               doc_name        date  \
# 10                   january-4-1980-speech-afghanistan  1980-01-04
# 27                   january-20-1949-inaugural-address  1949-01-20
# 32   march-15-1952-columbia-scholastic-press-associ...  1952-03-15
# 39    september-18-1948-whistlestop-tour-chariton-iowa  1948-09-18
# 40   september-18-1948-whistlestop-tour-trenton-mis...  1948-09-18
# 53   february-9-2010-news-conference-congressional-...  2010-02-09
# 96   december-24-1943-fireside-chat-27-tehran-and-c...  1943-12-24
# 97   december-29-1940-fireside-chat-16-arsenal-demo...  1940-12-29
# 108        july-19-1940-democratic-national-convention  1940-07-19
# 118             june-5-1944-fireside-chat-29-fall-rome  1944-06-05
# 126  may-27-1941-fireside-chat-17-unlimited-nationa...  1941-05-27
# 132       october-31-1936-speech-madison-square-garden  1936-10-31
# 137  september-6-1936-fireside-chat-8-farmers-and-l...  1936-09-06
# 145              december-8-1993-remarks-signing-nafta  1993-12-08
# 161            july-19-1995-address-affirmative-action  1995-07-19
# 169          may-5-1993-remarks-operation-restore-hope  1993-05-05
# 177  september-13-1993-remarks-signing-israeli-pale...  1993-09-13
# 182     december-5-1840-fourth-annual-message-congress  1840-12-05
# 183  february-16-1839-message-regarding-disputes-ma...  1839-02-16
# 184  january-2-1841-special-message-about-desctruct...  1841-01-02
# 204  july-18-1868-message-proposing-constitutional-...  1868-07-18
# 214  march-25-1868-veto-message-legislation-amendin...  1868-03-25
# 217  may-29-1865-message-reestablishing-governments...  1865-05-29
# 246                january-17-1968-state-union-address  1968-01-17
# 254  july-2-1964-remarks-upon-signing-civil-rights-...  1964-07-02
# 258         july-27-1967-speech-nation-civil-disorders  1967-07-27
# 264                june-30-1966-remarks-omaha-nebraska  1966-06-30
# 285  october-17-1966-remarks-departing-asia-pacific...  1966-10-17
# 286  october-18-1964-report-nation-events-china-and...  1964-10-18
# 294       december-11-1961-remarks-un-delegation-women  1961-12-11
# 297     february-21-1961-remarks-youth-fitness-program  1961-02-21
# 316  march-23-1962-address-university-california-be...  1962-03-23
# 320               may-3-1961-remarks-george-washington  1961-05-03
# 329  september-12-1960-address-greater-houston-mini...  1960-09-12
