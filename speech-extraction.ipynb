# %%
from __future__ import print_function
import urllib.request, json, urllib.parse , requests, sys
import pandas as pd
import random

# %% [markdown]
# ## 1. Data Gathering

# %% [markdown]
# ### 1.1 Extract Speeches

# %%
republican_list = [
    'Chester A. Arthur',
    'George H. W. Bush',
    'George W. Bush',
    'Calvin Coolidge',
    'Dwight D. Eisenhower',
    'Gerald Ford',
    'James A. Garfield',
    'Ulysses S. Grant',
    'Warren G. Harding',
    'Benjamin Harrison',
    'Rutherford B. Hayes',
    'Herbert Hoover',
    'William McKinley',
    'Richard M. Nixon',
    'Ronald Reagan',
    'Theodore Roosevelt',
    'William Taft',
    'Donald Trump'
]

democratic_list = [
    'Joe Biden',
    'James Buchanan',
    'Jimmy Carter',
    'Grover Cleveland',
    'Bill Clinton',
    'Andrew Jackson',
    'Andrew Johnson',
    'Lyndon B. Johnson',
    'John F. Kennedy',
    'Barack Obama',
    'Franklin Pierce',
    'James K. Polk',
    'Franklin D. Roosevelt',
    'Harry S. Truman',
    'Martin Van Buren',
    'Woodrow Wilson'
]

# %%
endpoint = "https://api.millercenter.org/speeches"

r = requests.post(url = endpoint)
data = r.json()
party_speeches = data["Items"]

while 'LastEvaluatedKey' in data:
  parameters = {"continue_president": data['LastEvaluatedKey']['president'], 
                "continue_doc_name": data['LastEvaluatedKey']['doc_name']}
  r = requests.post(url = endpoint, params = parameters)
  data = r.json()
  party_speeches += data["Items"]

# %% [markdown]
# ### 1.2 Stratify and Random Sample for each Party

# %%
party_speeches_df = pd.DataFrame(party_speeches)
party_speeches_df.head()
# Out:
#                                             doc_name        date  \
# 0                april-18-1977-address-nation-energy  1977-04-18
# 1        april-25-1980-statement-iran-rescue-mission  1980-04-25
# 2  august-14-1980-acceptance-speech-democratic-na...  1980-08-14
# 3  december-15-1978-speech-establishing-diplomati...  1978-12-15
# 4      february-2-1977-report-american-people-energy  1977-02-02
#
#                                           transcript     president  \
# 0  Good evening.\r\nTonight I want to have an unp...  Jimmy Carter
# 1  Late yesterday, I cancelled a carefully planne...  Jimmy Carter
# 2  Fellow Democrats, fellow citizens:\r\n\r\nI th...  Jimmy Carter
# 3  Good evening.\r\nI would like to read a joint ...  Jimmy Carter
# 4  Good evening.\r\nTomorrow will be two weeks si...  Jimmy Carter
#
#                                                title
# 0    April 18, 1977: Address to the Nation on Energy
# 1  April 25, 1980: Statement on the Iran Rescue M...
# 2  August 14, 1980: Acceptance Speech at the Demo...
# 3  December 15, 1978: Speech on Establishing Dipl...
# 4  February 2, 1977: Report to the American Peopl...

# %%
republican_speeches_df, democratic_speeches_df = pd.DataFrame(), pd.DataFrame()
for index, row in party_speeches_df.iterrows():
    if row["president"] in republican_list:
        republican_speeches_df = republican_speeches_df.append(row)
    elif row["president"] in democratic_list:
        democratic_speeches_df = democratic_speeches_df.append(row)

democratic_speeches_df.reset_index(drop = True, inplace=True)
republican_speeches_df.reset_index(drop = True, inplace=True)

# %%
republican_rand_indices, democratic_rand_indices = random.sample(range(len(republican_speeches_df)-1),50), random.sample(range(len(democratic_speeches_df)-1),50)

# %%
for index, row in republican_speeches_df.iterrows():
    if index not in republican_rand_indices:
        republican_speeches_df.drop(index, inplace=True)

for index, row in democratic_speeches_df.iterrows():
    if index not in democratic_rand_indices:
        democratic_speeches_df.drop(index, inplace=True)

# %%
rs_democratic_speeches_df = democratic_speeches_df.copy()
rs_democratic_speeches_df.head(3)
# Out:
#                                              doc_name        date  \
# 2   august-14-1980-acceptance-speech-democratic-na...  1980-08-14
# 7                   january-20-1977-inaugural-address  1977-01-20
# 13     may-22-1977-university-notre-dame-commencement  1977-05-22
#
#                                            transcript     president  \
# 2   Fellow Democrats, fellow citizens:\r\n\r\nI th...  Jimmy Carter
# 7   For myself and for our Nation, I want to thank...  Jimmy Carter
# 13  To Father Hesburgh and the great faculty of No...  Jimmy Carter
#
#                                                 title
# 2   August 14, 1980: Acceptance Speech at the Demo...
# 7                 January 20, 1977: Inaugural Address
# 13  May 22, 1977: University of Notre Dame Commenc...

# %%
rs_republican_speeches_df = republican_speeches_df.copy()
rs_republican_speeches_df.head(3)
# Out:
#                                              doc_name        date  \
# 4               december-5-1898-second-annual-message  1898-12-05
# 21      august-23-1984-republican-national-convention  1984-08-23
# 25  december-23-1981-address-nation-christmas-and-...  1981-12-23
#
#                                            transcript         president  \
# 4   To the Senate and House of Representatives: No...  William McKinley
# 21  Mr. Chairman, Mr. Vice President, delegates to...     Ronald Reagan
# 25  Good evening.\r\n\r\nAt Christmas time, every ...     Ronald Reagan
#
#                                                 title
# 4             December 5, 1898: Second Annual Message
# 21    August 23, 1984: Republican National Convention
# 25  December 23, 1981: Address to the Nation on Ch...

# %% [markdown]
# ## 2. NLP Analysis

# %% [markdown]
# ### 2.1 Preprocessing

# %%
import string
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
import nltk
from nltk.stem import WordNetLemmatizer

# %%
punctuation_strings = string.punctuation+("’")
spacy_stop_words = list(STOP_WORDS)
nlp = English()
nlp_lemm = spacy.load("en_core_web_sm")

# %%
# Remove stop words from text and calculate average # of words per sentence.
def clean_text(text):
    tokenized_sentences = nltk.sent_tokenize(text)
    word_tokens = list()
    total_sentence_len = 0
    for tokenized_sentence in tokenized_sentences:
        doc = nlp_lemm(tokenized_sentence)
        sentence_words = [word.lemma_.lower() for word in doc 
                    if str(word).lower() not in spacy_stop_words and 
                    str(word).lower() not in punctuation_strings and 
                    not nlp.vocab[str(word)].is_stop and
                    not str(word).lower().isdigit() and
                    str(word).isalpha()]
        # lemmatizer = WordNetLemmatizer()
        # sentence_words = [lemmatizer.lemmatize(word.lower()) for word in nltk.word_tokenize(tokenized_sentence) 
        #             if word.lower() not in spacy_stop_words and 
        #             word.lower() not in punctuation_strings and 
        #             not nlp.vocab[word].is_stop and
        #             not word.lower().isdigit() and
        #             word.isalpha()]
        total_sentence_len += len(sentence_words)
        word_tokens += sentence_words
        
    return {"Word Tokens": word_tokens, "Average Sentence Length": total_sentence_len / len(tokenized_sentences)}

# %%
def clean_df_text(df):
    clean_transcript, avg_sentence_length = [], []
    for index, row in df.iterrows():
        clean_text_output = clean_text(row["transcript"])
        clean_transcript.append(clean_text_output["Word Tokens"])
        avg_sentence_length.append(clean_text_output["Average Sentence Length"])
    df["clean transcript"] = clean_transcript
    df["avg_sentence_length"] = avg_sentence_length

# %%
clean_df_text(rs_republican_speeches_df)
clean_df_text(rs_democratic_speeches_df)

# %%
rs_democratic_speeches_df
# Out:
#                                               doc_name        date  \
# 2    august-14-1980-acceptance-speech-democratic-na...  1980-08-14
# 7                    january-20-1977-inaugural-address  1977-01-20
# 13      may-22-1977-university-notre-dame-commencement  1977-05-22
# 23                 april-16-1945-first-speech-congress  1945-04-16
# 26                    january-15-1953-farewell-address  1953-01-15
# 51     february-24-2009-address-joint-session-congress  2009-02-24
# 56                   january-20-2009-inaugural-address  2009-01-20
# 58            january-21-2013-second-inaugural-address  2013-01-21
# 60            january-25-2011-2011-state-union-address  2011-01-25
# 64          january-29-2013-remarks-immigration-reform  2013-01-29
# 84   november-6-2012-2012-election-night-victory-sp...  2012-11-06
# 97   december-29-1940-fireside-chat-16-arsenal-demo...  1940-12-29
# 128  november-14-1937-fireside-chat-11-unemployment...  1937-11-14
# 146    february-17-1993-address-joint-session-congress  1993-02-17
# 148  february-5-1993-remarks-signing-family-medical...  1993-02-05
# 152                   january-20-1997-second-inaugural  1997-01-20
# 175  october-6-1996-presidential-debate-senator-bob...  1996-10-06
# 183  february-16-1839-message-regarding-disputes-ma...  1839-02-16
# 187  november-21-1838-message-regarding-disturbance...  1838-11-21
# 196      december-3-1867-third-annual-message-congress  1867-12-03
# 228                    august-18-1967-press-conference  1967-08-18
# 241  february-29-1964-press-conference-state-depart...  1964-02-29
# 245                january-14-1969-state-union-address  1969-01-14
# 250                         january-8-1964-state-union  1964-01-08
# 258         july-27-1967-speech-nation-civil-disorders  1967-07-27
# 262    june-11-1965-remarks-manned-space-flight-center  1965-06-11
# 265  june-4-1965-remarks-howard-university-commence...  1965-06-04
# 270             march-23-1966-speech-foreign-institute  1966-03-23
# 272  march-26-1965-statement-arrests-violo-liuzzo-m...  1965-03-26
# 283              november-28-1963-thanksgiving-message  1963-11-28
# 293           april-27-1961-president-and-press-speech  1961-04-27
# 338  december-17-1895-message-regarding-venezuelan-...  1895-12-17
# 353  january-28-1895-message-regarding-financial-cr...  1895-01-28
# 356             june-12-1895-declaration-us-neutrality  1895-06-12
# 365  october-1-1888-message-regarding-chinese-exclu...  1888-10-01
# 370  december-12-1833-message-constitutional-rights...  1833-12-12
# 375     december-6-1830-second-annual-message-congress  1830-12-06
# 383                             july-10-1832-bank-veto  1832-07-10
# 402  march-11-2021-remarks-anniversary-coronavirus-...  2021-03-12
# 405        march-31-2021-announcing-american-jobs-plan  2021-03-31
# 411   april-13-1846-message-regarding-cherokee-indians  1846-04-13
# 419               december-2-1845-first-annual-message  1845-12-02
# 422               december-7-1847-third-annual-message  1847-12-07
# 431  march-24-1846-message-regarding-increase-milit...  1846-03-24
